# %%
import torch
import torchvision

# 1. Check PyTorch version
print("PyTorch version:", torch.__version__)

# 2. Check torchvision version
print("TorchVision version:", torchvision.__version__)

# 3. Check if CUDA is available (if you installed the CUDA-enabled version)
print("CUDA available:", torch.cuda.is_available())

# 4. If GPU is available, check the number of GPUs
if torch.cuda.is_available():
    print("Number of available GPUs:", torch.cuda.device_count())
    print("Current GPU name:", torch.cuda.get_device_name(0))
# Out:
# PyTorch version: 2.10.0+cu130
# TorchVision version: 0.25.0+cu130
# CUDA available: True
# Number of available GPUs: 1
# Current GPU name: NVIDIA GeForce RTX 5070 Ti Laptop GPU
